# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
! pip install gmaps
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df=pd.read_csv('../Weatherpy/city_weather.csv')
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.head()
# Out:
#              City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande  38.5167  -28.7000     14.80        78          99
# 1           Kidal  18.4411    1.4078     28.90         8           0
# 2           Jvara  41.5251   44.3472     12.00        87          90
# 3            Asău  46.4333   26.4000      2.22        65          63
# 4     Yellowknife  62.4560 -114.3525     -8.89        57          75
#
#    Wind_Speed Country        Date
# 0       12.85      PT  1619230113
# 1        4.09      ML  1619230114
# 2        2.06      GE  1619230114
# 3        1.69      RO  1619230012
# 4        4.12      CA  1619230104

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(df[['Lat','Lng']], weights=df['Humidity'], 
                                 dissipating=False, max_intensity=100,
                                 point_radius=2)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
hotel_df=df.loc[(df['Max_Temp'].between(20,25)) & (df['Wind_Speed']<3) & (df['Cloudiness']<10)]
hotel_df.reset_index(inplace=True,drop=True)
hotel_df
# Out:
#          City      Lat       Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0       Airai  -8.9266  125.4092     23.43        48           5        1.40
# 1   Caravelas -17.7125  -39.2481     22.99        86           0        2.04
# 2    Buraidah  26.3260   43.9750     23.00        25           0        1.54
# 3     Caborca  30.5838 -111.1010     25.00        25           0        2.24
# 4  Oro Valley  32.3909 -110.9665     25.00        21           2        0.89
# 5       Nizwá  22.9333   57.5333     24.28        26           0        0.49
# 6         Voi  -3.3945   38.5630     21.34        90           8        2.22
# 7   Kalur Kot  32.1564   71.2594     22.06        41           0        2.25
# 8     Camapuã -19.5314  -54.0439     21.25        38           0        2.53
# 9      Casino -28.8667  153.0500     22.00        53           0        1.54
#
#   Country        Date
# 0      TL  1619230155
# 1      BR  1619230111
# 2      SA  1619230176
# 3      MX  1619230193
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
Caravelas=requests.get('https://maps.googleapis.com/maps/api/place/\
nearbysearch/json?key='+g_key+'&radius=5000&type=lodging&location=-17.7125,-39.2481').json()

# %%
Caravelas
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.7379707, 'lng': -39.2589096},
#     'viewport': {'northeast': {'lat': -17.7365489197085,
#       'lng': -39.25753821970849},
#      'southwest': {'lat': -17.7392468802915, 'lng': -39.26023618029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada dos Navegantes',
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110604417840892784095">Onaldo Rocha dos Anjos</a>'],
#      'photo_reference': 'ATtYBwL-m5KbQ8blN0UN3EJJ5d-E3ENpIOY3gHhjsrw9sCaYkPTSpknxOFsfq1CBJ5trNt1F1XUabZfqmRSKJBkoXg_hyHsPEIXfbDivGaPBXR_6JwRm7td0oAGD132qQ2J7sz38Qb3YJtB2jhinbi8cRBrx_QC6r7j01gZDgUHKMGUVCu8m',
#      'width': 1280}],
#    'place_id': 'ChIJVVgc5WnXNAcRLGgmGSFNxr0',
#    'plus_code': {'compound_code': '7P6R+RC Caravelas, BA, Brazil',
# ...

# %%
Caravelas['results'][0]['name']
# Out:
# 'Pousada dos Navegantes'

# %%
base_url='https://maps.googleapis.com/maps/api/place/\
nearbysearch/json?key='+g_key+'&radius=5000&type=lodging&location='

# %%
hotelname=[]

for x,y in zip(hotel_df['Lat'],hotel_df['Lng']):
    try:
        response=requests.get(base_url+str(x)+','+str(y)).json()
        hotelname.append(response['results'][0]['name'])
    except:
        hotelname.append('No Lodging')
        print(f'there is no loding near {str(x)},{str(y)}')

# %%
hotel_df['Hotel_Name']=hotelname
hotel_df
# Out:
# <ipython-input-12-47ef3e48d17a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel_Name']=hotelname
#          City      Lat       Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0       Airai  -8.9266  125.4092     23.43        48           5        1.40
# 1   Caravelas -17.7125  -39.2481     22.99        86           0        2.04
# 2    Buraidah  26.3260   43.9750     23.00        25           0        1.54
# 3     Caborca  30.5838 -111.1010     25.00        25           0        2.24
# 4  Oro Valley  32.3909 -110.9665     25.00        21           2        0.89
# 5       Nizwá  22.9333   57.5333     24.28        26           0        0.49
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel_Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
